# %% [markdown]
# ## Лабораторная работа №1
# ### Задание 1
# Реализуйте функцию sum_distance(from, to), которая суммирует все числа от значения from до величины to включительно.
# Примечание: если пользователь задаст первое число, которое окажется больше второго, просто поменяйте их местами.

# %%
def sum_distance(from_num, to_num):
    # Меняем местами значения, если первое больше второго
    if from_num > to_num:
        from_num, to_num = to_num, from_num
        print(f'Меняем местами: {from_num} и {to_num}')
    # Суммируем все числа в указанном диапазоне
    total_sum = sum(range(from_num, to_num + 1))  # использование sum и range для упрощения
    return total_sum

# Ввод данных
from_num = int(input('Введите первое число: '))
to_num = int(input('Введите второе число: '))

# Вывод результата
print(f'Сумма чисел от {from_num} до {to_num}: {sum_distance(from_num, to_num)}')
# Out:
# Введите первое число: 2
# Введите второе число: 5
# Сумма чисел от 2 до 5: 14

# %% [markdown]
# ### Задание 2
# Реализуйте функцию trim_and_repeat(), которая принимает три параметра:
# ● строку;
# ● offset — число символов, на которое нужно обрезать строку слева;
# ● repetitions — сколько раз нужно повторить строку перед возвратом получившейся строки.
# Число символов для среза по умолчанию равно 0, а количество повторений — 1.
# Функция должна возвращать полученную строку.

# %%
def trim_and_repeat(string, offset=0, repetitions=1):
    # Обрезаем строку начиная с индекса offset
    trimmed_string = string[offset:]
    # Повторяем обрезанную строку
    repeated_string = trimmed_string * repetitions
    return repeated_string

# Ввод данных
string = input('Введите фразу: ')
offset = int(input('Сколько режем слева? '))
repetitions = int(input('Повторяем сколько раз? '))

# Вывод результата
print(f'===Результат: {trim_and_repeat(string, offset, repetitions)}===')
# Out:
# Введите фразу: 12345
# Сколько режем слева? 1
# Повторяем сколько раз? 2
# Результат: 23452345
